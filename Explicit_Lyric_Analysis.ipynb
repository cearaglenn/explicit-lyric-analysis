# %% [markdown]
# # Explicit Lyric Analysis
#
# Inspiration: There are many opinions that songs now have more explicit words than songs in the past.
#
# What I'm Gonna Do: I will perform an explicit word count across 7 decades to find if there is any truth to the statement above.
#
# TLDR - I found that the later decades (2000s vs 2010s) did indeed include more explicit words compared to earlier decades. The 2000s had the most explicit words found per songs (average: 1.73 words, median: 1 word). When compared to the 1950s, the 2000s significantly had more explicit words in the lyrics.
#
# More Results Can Be Found under the Results header.
#
# If you would like to view the Tableau Dashboard I built, here's the link: [Tableau Dashboard](https://public.tableau.com/app/profile/ceara.glenn/viz/SongsExplicitWordCountByDecade/YTDashboard)

# %% [markdown]
# ## Sources
#
# * Genius API
# * Spotify API
# * [Carnegie Mellon Explicit Word List](https://www.cs.cmu.edu/~biglou/resources/)
# * [YouTube Explicit Word List](https://www.freewebheaders.com/youtube-blacklist-words-list-youtube-comment-moderation/)

# %% [markdown]
# ## Import Libraries

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from lyricsgenius import Genius

import pandas as pd
import numpy as np
import scipy.stats as ss
import re
import time
import string
import contractions
from operator import itemgetter

import fuzzywuzzy
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

import nltk
#nltk.download('stopwords')
en_stop = nltk.corpus.stopwords.words('english')
# Out:
# c:\Users\Ce\Documents\Projects\YouTube\yt\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
from collections import defaultdict

# %% [markdown]
# ## Set Credentials
#
# You can retrieve Spotify and Genius credentials by setting up a developer's profile on those sites.

# %%
#spotify
Screds = SpotifyClientCredentials(
    client_id=Spotify_id,
    client_secret=Spotify_secret
)
sp = spotipy.Spotify(auth_manager=Screds)

#genius
Gcreds = Genius_key
genius = Genius(Gcreds, sleep_time=1, retries=1, timeout=10, remove_section_headers=True)

# %% [markdown]
# ## Pull The Decades Playlists from Spotify
#
# I located playlists I wanted to use from Spotify. I retrieved the playlist ids from the playlist url.

# %%
#All Out 50s
fifties = sp.playlist_tracks("37i9dQZF1DWSV3Tk4GO2fq")#https://open.spotify.com/playlist/37i9dQZF1DWSV3Tk4GO2fq?si=bc646e564ef246c6
fifties_b = sp.playlist_tracks("37i9dQZF1DWSV3Tk4GO2fq", offset=100)
#All Out 60s
sixties = sp.playlist_tracks("37i9dQZF1DXaKIA8E7WcJj")#https://open.spotify.com/playlist/37i9dQZF1DXaKIA8E7WcJj?si=699d64348b8b48eb
sixties_b = sp.playlist_tracks("37i9dQZF1DXaKIA8E7WcJj", offset=100)
#All Out 70s
seventies = sp.playlist_tracks("37i9dQZF1DWTJ7xPn4vNaz")#https://open.spotify.com/playlist/37i9dQZF1DWTJ7xPn4vNaz?si=662ccc35b56b4ba6
seventies_b = sp.playlist_tracks("37i9dQZF1DWTJ7xPn4vNaz", offset=100)
#All Out 80s
eighties = sp.playlist_tracks("37i9dQZF1DX4UtSsGT1Sbe")#"https://open.spotify.com/playlist/37i9dQZF1DX4UtSsGT1Sbe?si=d53af64c58d84183"
eighties_b = sp.playlist_tracks("37i9dQZF1DX4UtSsGT1Sbe", offset=100)
#All Out 90s
nineties = sp.playlist_tracks("37i9dQZF1DXbTxeAdrVG2l")#"https://open.spotify.com/playlist/37i9dQZF1DXbTxeAdrVG2l?si=de39da16846e4703"
nineties_b = sp.playlist_tracks("37i9dQZF1DXbTxeAdrVG2l", offset=100)
#All Out 00s
millennium = sp.playlist_tracks("37i9dQZF1DX4o1oenSJRJd")#"https://open.spotify.com/playlist/37i9dQZF1DX4o1oenSJRJd?si=ab4ccbbb7726487b"
millennium_b = sp.playlist_tracks("37i9dQZF1DX4o1oenSJRJd", offset=100)
#All Out 10s
twenty10s = sp.playlist_tracks("37i9dQZF1DX5Ejj0EkURtP")#"https://open.spotify.com/playlist/37i9dQZF1DX5Ejj0EkURtP?si=82c356e32cdb40dd"
twenty10s_b = sp.playlist_tracks("37i9dQZF1DX5Ejj0EkURtP", offset=100)

# %%
#an example of what the raw data looks like once pulled from Spotify API
fifties
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSV3Tk4GO2fq/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-04-28T06:38:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/43ZHCT0cAZBISjO8DG9PnE'},
#        'href': 'https://api.spotify.com/v1/artists/43ZHCT0cAZBISjO8DG9PnE',
#        'id': '43ZHCT0cAZBISjO8DG9PnE',
#        'name': 'Elvis Presley',
#        'type': 'artist',
#        'uri': 'spotify:artist:43ZHCT0cAZBISjO8DG9PnE'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0C3t1htEDTFKcg7F2rNbek'},
#      'href': 'https://api.spotify.com/v1/albums/0C3t1htEDTFKcg7F2rNbek',
#      'id': '0C3t1htEDTFKcg7F2rNbek',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27320ee3e86e17f17239bef1f76',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0220ee3e86e17f17239bef1f76',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485120ee3e86e17f17239bef1f76',
#        'width': 64}],
#      'name': "Elvis' Golden Records",
#      'release_date': '1958-03-21',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0C3t1htEDTFKcg7F2rNbek'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/43ZHCT0cAZBISjO8DG9PnE'},
#       'href': 'https://api.spotify.com/v1/artists/43ZHCT0cAZBISjO8DG9PnE',
#       'id': '43ZHCT0cAZBISjO8DG9PnE',
#       'name': 'Elvis Presley',
#       'type': 'artist',
#       'uri': 'spotify:artist:43ZHCT0cAZBISjO8DG9PnE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 122893,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC15602859'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/01u6AEzGbGbQyYVdxajxqk'},
#     'href': 'https://api.spotify.com/v1/tracks/01u6AEzGbGbQyYVdxajxqk',
#     'id': '01u6AEzGbGbQyYVdxajxqk',
#     'is_local': False,
#     'name': "Don't Be Cruel",
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7a3c50df53ab91b8664abf39de5fea813e55c3b4?cid=8ebac1a0860c4802a2a4aac23fe89485',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:01u6AEzGbGbQyYVdxajxqk'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-28T06:38:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Mxqyy3pSjf8kZZL4QVxS0'},
#        'href': 'https://api.spotify.com/v1/artists/1Mxqyy3pSjf8kZZL4QVxS0',
#        'id': '1Mxqyy3pSjf8kZZL4QVxS0',
#        'name': 'Frank Sinatra',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4kca7vXd1Wo5GE2DMafvMc'},
#      'href': 'https://api.spotify.com/v1/albums/4kca7vXd1Wo5GE2DMafvMc',
#      'id': '4kca7vXd1Wo5GE2DMafvMc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b9ea1c69fe9efbdc2df85a95',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b9ea1c69fe9efbdc2df85a95',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b9ea1c69fe9efbdc2df85a95',
#        'width': 64}],
#      'name': "Songs For Swingin' Lovers! (Remastered)",
#      'release_date': '1956-03',
#      'release_date_precision': 'month',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:4kca7vXd1Wo5GE2DMafvMc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Mxqyy3pSjf8kZZL4QVxS0'},
#       'href': 'https://api.spotify.com/v1/artists/1Mxqyy3pSjf8kZZL4QVxS
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f1ba866a9dae60ca159fec52aac4ad36bce32d57?cid=8ebac1a0860c4802a2a4aac23fe89485',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5yQ9iMZXGcr5rlO4hoLsP4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-28T06:38:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5V0MlUE1Bft0mbLlND7FJz'},
#        'href': 'https://api.spotify.com/v1/artists/5V0MlUE1Bft0mbLlND7FJz',
#        'id': '5V0MlUE1Bft0mbLlND7FJz',
#        'name': 'Ella Fitzgerald',
#        'type': 'artist',
#        'uri': 'spotify:artist:5V0MlUE1Bft0mbLlND7FJz'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5PwtIbLxUKAgPU05eqT6ja'},
#      'href': 'https://api.spotify.com/v1/albums/5PwtIbLxUKAgPU05eqT6ja',
#      'id': '5PwtIbLxUKAgPU05eqT6ja',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf2c87b8c8191a711796cc61',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf2c87b8c8191a711796cc61',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf2c87b8c8191a711796cc61',
#        'width': 64}],
#      'name': 'Ella & Friends',
#      'release_date': '1996-06-04',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:5PwtIbLxUKAgPU05eqT6ja'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5V0MlUE1Bft0mbLlND7FJz'},
#       'href': 'https://api.spotify.com/v1/artists/5V0MlUE1Bft0mbLlND7FJz',
#       'id': '5V0MlUE1Bft0mbLlND7FJz',
#       'name': 'Ella Fitzgerald',
#       'type': 'artist',
#       'uri': 'spotify:artist:5V0MlUE1Bft0mbLlND7FJz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/19eLuQmk9aCobbVDHc6eek'},
#       'href': 'https://api.spotify.com/v1/artists/19eLuQmk9aCobbVDHc6eek',
#       'id': '19eLuQmk9aCobbVDHc6eek',
#       'name': 'Louis Armstrong',
#       'type': 'artist',
#       'uri': 'spotify:artist:19eLuQmk9aCobbVDHc6eek'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 185066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC15076750'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3vFVS2WYHDG4KkWCNecvpn'},
#     'href': 'https://api.spotify.com/v1/tracks/3vFVS2WYHDG4KkWCNecvpn',
#     'id': '3vFVS2WYHDG4KkWCNecvpn',
#     'is_local': False,
#     'name': 'Dream A Little Dream Of Me',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3vFVS2WYHDG4KkWCNecvpn'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-28T06:38:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3wYyutjgII8LJVVOLrGI0D'},
#        'href': 'https://api.spotify.com/v1/artists/3wYyutjgII8LJVVOLrGI0D',
#        'id': '3wYyutjgII8LJVVOLrGI0D',
#        'name': 'Buddy Holly',
#        'type': 'artist',
#        'uri': 'spotify:artist:3wYyutjgII8LJVVOLrGI0D'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0KHc3cD7pAOAieo9lPWXkY'},
#      'href': 'https://api.spotify.com/v1/albums/0KHc3cD7pAOAieo9lPWXkY',
#      'id': '0KHc3cD7pAOAieo9lPWXkY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273085751ccca901e9bbc25a816',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02085751ccca901e9bbc25a816',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851085751ccca901e9bbc25a816',
#        'width': 64}],
#      'name': "That'll Be The Day",
#      'release_date': '1958-06-01',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0KHc3cD7pAOAieo9lPWXkY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3wYyutjgII8LJVVOLrGI0D'},
#       'href': 'https://api.spotify.com/v1/artists/3wYyutjgII8LJVVOLrGI0D',
#       'id': '3wYyutjgII8LJVVOLrGI0D',
#       'name': 'Buddy Holly',
#       'type': 'artist',
#       'uri': 'spotify:artist:3wYyutjgII8LJVVOLrGI0D'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 150133,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC15600442'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50RwvvEKX5Q7AZt8FTAwIF'},
#     'href': 'https://api.spotify.com/v1/tracks/50RwvvEKX5Q7AZt8FTAwIF',
#     'id': '50RwvvEKX5Q7AZt8FTAwIF',
#     'is_local': False,
#     'name': "That'll Be The Day",
#     'popularity': 63,
#     'preview_url': None,
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:50RwvvEKX5Q7AZt8FTAwIF'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-28T06:38:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/09C0xjtosNAIXP36wTnWxd'},
#        'href': 'https://api.spotify.com/v1/artists/09C0xjtosNAIXP36wTnWxd',
#        'id': '09C0xjtosNAIXP36wTnWxd',
#        'name': 'Fats Domino',
#        'type': 'artist',
#        'uri': 'spotify:artist:09C0xjtosNAIXP36wTnWxd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3vte37u7rIAmMZJwNyJSjf'},
#      'href': 'https://api.spotify.com/v1/albums/3vte37u7rIAmMZJwNyJSjf',
#      'id': '3vte37u7rIAmMZJwNyJSjf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27374e3823e9643fabc830851dd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0274e3823e9643fabc830851dd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485174e3823e9643fabc830851dd',
#        'width': 64}],
#      'name': 'Fats Domino Swings',
#      'release_date': '1959-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3vte37u7rIAmMZJwNyJSjf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/09C0xjtosNAIXP36wTnWxd'},
#       'href': 'https://api.spotify.com/v1/artists/09C0xjtosNAIXP36wTnWxd',
#       'id': '09C0xjtosNAIXP36wTnWxd',
#       'name': 'Fats Domino',
#       'type': 'artist',
#       'uri': 'spotify:artist:09C0xjtosNAIXP36wTnWxd'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 147880,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEM38700119'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/06PdA0DLgF4BfAeUNZAbFG'},
#     'href': 'https://api.spotify.com/v1/tracks/06PdA0DLgF4BfAeUNZAbFG',
#     'id': '06PdA0DLgF4BfAeUNZAbFG',
#     'is_local': False,
#     'name': 'Blueberry Hill',
#     'popularity': 61,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:06PdA0DLgF4BfAeUNZAbFG'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-28T06:38:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2YVKgCKM0IgHxxmLzWutm3'},
#      'href': 'https://api.spotify.com/v1/albums/2YVKgCKM0IgHxxmLzWutm3',
#      'id': '2YVKgCKM0IgHxxmLzWutm3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/2ee7d6d9781fa51ff685b9def6b6c9850f6bd123',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/9a68b52933af23a42de39b07a917ef5aa9259a9f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/37dc244330f39011c0bb013291525833b88060cc',
#        'width': 64}],
#      'name': 'Top 100 Hits - Rock And Roll',
#      'release_date': '2012-06-14',
#      'release_date_precision': 'day',
#      'total_tracks': 100,
#      'type': 'album',
#      'uri': 'spotify:album:2YVKgCKM0IgHxxmLzWutm3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ACplpEqD6JIVgKrafauzs'},
#       'href': 'https://api.spotify.com/v1/artists/4ACplpEqD6JIVgKrafauzs',
#       'id': '4ACplpEqD6JIVgKrafauzs',
#       'name': 'The Everly Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:4ACplpEqD6JIVgKrafauzs'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 147586,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB8LG1200129'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1vVY5vd4kowd70TdTuEjfV'},
#     'href': 'https://api.spotify.com/v1/tracks/1vVY5vd4kowd70TdTuEjfV',
#     'id': '1vVY5vd4kowd70TdTuEjfV',
#     'is_local': False,
#     'name': '(‘Til) I Kissed You',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 29,
#     'type': 'track',
#     'uri': 'spotify:track:1vVY5vd4kowd70TdTuEjfV'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-28T06:38:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49e4v89VmlDcFCMyDv9wQ9'},
#        'href': 'https://api.spotify.com/v1/artists/49e4v89VmlDcFCMyDv9wQ9',
#        'id': '49e4v89VmlDcFCMyDv9wQ9',
#        'name': 'Dean Martin',
#        'type': 'artist',
#        'uri': 'spotify:artist:49e4v89VmlDcFCMyDv9wQ9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/31Mwr76okDPhxDxK6OaL1N'},
#      'href': 'https://api.spotify.com/v1/albums/31Mwr76okDPhxDxK6OaL1N',
#      'id': '31Mwr76okDPhxDxK6OaL1N',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27375120bfb3b80e157d4615518',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0275120bfb3b80e157d4615518',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485175120bfb3b80e157d4615518',
#        'width': 64}],
#      'name': 'The Capitol Years',
#      'release_date': '1989-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:31Mwr76okDPhxDxK6OaL1N'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49e4v89VmlDcFCMyDv9wQ9'},
#       'href': 'https://api.spotify.com/v1/artists/49e4v89VmlDcFCMyDv9wQ9',
#       'id': '49e4v89VmlDcFCMyDv9wQ9',
#       'name': 'Dean Martin',
#       'type': 'artist',
#       'uri': 'spotify:artist:49e4v89VmlDcFCMyDv9wQ9'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0liyb0PPDyu3pfG7WZtsxO'},
#       'href': 'https://api.spotify.com/v1/artists/0liyb0PPDyu3pfG7WZtsxO',
#       'id': '0liyb0PPDyu3pfG7WZtsxO',
#       'name': 'Dick Stabile And His Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:0liyb0PPDyu3pfG7WZtsxO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 188266,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA25300027'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3x6wVKXfCm85Pw7gYo0rqq'},
#     'href': 'https://api.spotify.com/v1/tracks/3x6wVKXfCm85Pw7gYo0rqq',
#     'id': '3x6wVKXfCm85Pw7gYo0rqq',
#     'is_local': False,
#     'name': "That's Amore",
#     'popularity': 53,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3x6wVKXfCm85Pw7gYo0rqq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-28T06:38:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
# ...
#       'id': '49e4v89VmlDcFCMyDv9wQ9',
#       'name': 'Dean Martin',
#       'type': 'artist',
#       'uri': 'spotify:artist:49e4v89VmlDcFCMyDv9wQ9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 181626,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA29801802'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5OkKOkdVTKFrYi6GWXkMzR'},
#     'href': 'https://api.spotify.com/v1/tracks/5OkKOkdVTKFrYi6GWXkMzR',
#     'id': '5OkKOkdVTKFrYi6GWXkMzR',
#     'is_local': False,
#     'name': 'Volare (Nel Blu Di Pinto Di Blu) - Remastered',
#     'popularity': 64,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5OkKOkdVTKFrYi6GWXkMzR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-28T06:38:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#        'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#        'id': '1YzCsTRb22dQkh9lghPIrp',
#        'name': 'Billie Holiday',
#        'type': 'artist',
#        'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7tsBTgXE5wZggdmh5qBhZH'},
#      'href': 'https://api.spotify.com/v1/albums/7tsBTgXE5wZggdmh5qBhZH',
#      'id': '7tsBTgXE5wZggdmh5qBhZH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733d6c3d9f588a257c4a563050',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023d6c3d9f588a257c4a563050',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513d6c3d9f588a257c4a563050',
#        'width': 64}],
#      'name': 'Lover Man',
#      'release_date': '1958-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7tsBTgXE5wZggdmh5qBhZH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#       'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#       'id': '1YzCsTRb22dQkh9lghPIrp',
#       'name': 'Billie Holiday',
#       'type': 'artist',
#       'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 185280,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC14975422'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4mQz22nF9cyWqwuErTqc6V'},
#     'href': 'https://api.spotify.com/v1/tracks/4mQz22nF9cyWqwuErTqc6V',
#     'id': '4mQz22nF9cyWqwuErTqc6V',
#     'is_local': False,
#     'name': 'Crazy He Calls Me',
#     'popularity': 56,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4mQz22nF9cyWqwuErTqc6V'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-28T06:38:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Mxqyy3pSjf8kZZL4QVxS0'},
#        'href': 'https://api.spotify.com/v1/artists/1Mxqyy3pSjf8kZZL4QVxS0',
#        'id': '1Mxqyy3pSjf8kZZL4QVxS0',
#        'name': 'Frank Sinatra',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7B45fvRtEecfSqKqUYXh6X'},
#      'href': 'https://api.spotify.com/v1/albums/7B45fvRtEecfSqKqUYXh6X',
#      'id': '7B45fvRtEecfSqKqUYXh6X',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273503b7b4db39f931b7188188b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02503b7b4db39f931b7188188b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851503b7b4db39f931b7188188b',
#        'width': 64}],
#      'name': "Sinatra And Swingin' Brass",
#      'release_date': '1962-07',
#      'release_date_precision': 'month',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7B45fvRtEecfSqKqUYXh6X'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Mxqyy3pSjf8kZZL4QVxS0'},
#       'href': 'https://api.spotify.com/v1/artists/1Mxqyy3pSjf8kZZL4QVxS0',
#       'id': '1Mxqyy3pSjf8kZZL4QVxS0',
#       'name': 'Frank Sinatra',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Mxqyy3pSjf8kZZL4QVxS0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 194093,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRH10800750'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3mKdw0slI6wmnb1FBrvwn2'},
#     'href': 'https://api.spotify.com/v1/tracks/3mKdw0slI6wmnb1FBrvwn2',
#     'id': '3mKdw0slI6wmnb1FBrvwn2',
#     'is_local': False,
#     'name': 'I Get A Kick Out Of You',
#     'popularity': 55,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3mKdw0slI6wmnb1FBrvwn2'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSV3Tk4GO2fq/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 150}

# %% [markdown]
# ## Building the Dataset
#
# In this step, I was creating an intermediate dataset from the Spotify data. This data will outline items like track name, album name, artist name(s), and explicit tag. I extract the data from the Spotify JSON dictionary and translate it so that it will be used to pull song lyrics from the Genius API.
#
# ****************************************************************************
# Below are the notes I took during analysis:
#
# Using songs pulled from ~10/7/2021~ 10/10/2021
#
# columns needed:
# * artist name
# * album name
# * featured artists
# * explicit tag
# * track name
# * track (true or false)
# * release date for song
# * album type (I think if it's a standalone single or apart of an album)
# * playlist id - gives me the decade
#
# columns added:
# * track_id from Spotify
# * flag for mutliple artists

# %%
#lambda functions created for the create_dataset function

#locate data within the json format for album
album_facts = lambda playlist, fact: [playlist["items"][num]["track"]["album"][fact] for num in range(len(playlist["items"]))]

#locate data within the json format for track
track_facts = lambda playlist, fact: [playlist["items"][num]["track"][fact] for num in range(len(playlist["items"]))]

# %%
#set up variables for the create_dataset function

#these are the features I want to pull from the album key in the json
album_features = ["release_date","type","name"]

#these are the features I want to pull from the track key in the json
track_features = ["explicit","track","name","id"]

#all of the results from the Spotify API pull put in a list
playlists = [fifties, fifties_b, sixties, sixties_b, seventies, seventies_b, 
             eighties, eighties_b, nineties, nineties_b, millennium, millennium_b,twenty10s,twenty10s_b]

# %%
def create_dataset(playlists,album_features,track_features):
    """
    This function will take the Spotify features from the JSON format and convert it into a pandas DataFrame.

    1) Create empty dataframe
    2) Iterate over each playlist and do the following:
        * Create an empty dataframe
        For the Track/Album Features
        * Retrieve the data using lambda function (album_facts or track_facts)
        * Create a column for the empty dataframe for each album/track feature
        For Playlist ID
        *Using regex, pull the playlist ID from the playlist link
        For Artists
        * Pull the artist key in the json
        * Create a column that says if the song has multiple artists (T/F)
        * Create column(s) for each artist in the song 
    3) Once the empty dataframe has been filled with all features from the playlist, the playlist dataframe
        will be appended to the overall dataframe

    Output: Pandas DataFrame filled with Spotify Data Needed for analysis
    """
    full_data = pd.DataFrame()
    for pl in playlists:
        songs = pd.DataFrame()
        for feature in album_features:
            facts = album_facts(pl, feature)
            songs["album_"+feature] = facts
        for feature in track_features:
            facts = track_facts(pl, feature)
            songs["track_"+feature] = facts
        songs["playlist_id"] = re.search(r"(?<=playlists/).*(?=/track)", pl["href"]).group(0)
        artists = list(list(map(itemgetter('name'), pl["items"][num]["track"]["artists"])) for num in range(len(pl["items"])))
        songs["multiple_artists"] = list(map(lambda x: True if len(x) > 1 else False, artists))
        artists_df = pd.DataFrame(artists, columns = ["Artist_"+str(i+1) for i in range(0,find_max(artists))])
        songs = pd.concat([songs,artists_df],axis=1)
        full_data = pd.concat([full_data,songs])
    return full_data

def find_max(List_of_Lists):
    """
    This function is to find the element in the list that has the most elements.
    Once I have that max number, this will become the number of columns that I will create for the artists.
    """
    maximum = 0
    for i in range(len(List_of_Lists)):
        num = len(List_of_Lists[i])
        if num > maximum:
            maximum = num
    return maximum

# %%
full_data = create_dataset(playlists,album_features,track_features)

# %%
full_data.head()
# Out:
#   album_release_date album_type                               album_name  \
# 0         1958-03-21      album                    Elvis' Golden Records
# 1            1956-03      album  Songs For Swingin' Lovers! (Remastered)
# 2         1995-01-01      album                 The Best Of The Platters
# 3               1959      album                             What'd I Say
# 4         1996-06-04      album                           Ella & Friends
#
#    track_explicit  track_track                                    track_name  \
# 0           False         True                                Don't Be Cruel
# 1           False         True  I've Got You Under My Skin - Remastered 1998
# 2           False         True                       Smoke Gets In Your Eyes
# 3           False         True                       What'd I Say, Pt. 1 & 2
# 4           False         True                    Dream A Little Dream Of Me
#
#                  track_id             playlist_id  multiple_artists  \
# 0  01u6AEzGbGbQyYVdxajxqk  37i9dQZF1DWSV3Tk4GO2fq             False
# 1  3aEJMh1cXKEjgh52claxQp  37i9dQZF1DWSV3Tk4GO2fq             False
# 2  307XEC1IUwUs9ojlEFwH7f  37i9dQZF1DWSV3Tk4GO2fq             False
# 3  5yQ9iMZXGcr5rlO4hoLsP4  37i9dQZF1DWSV3Tk4GO2fq             False
# 4  3vFVS2WYHDG4KkWCNecvpn  37i9dQZF1DWSV3Tk4GO2fq              True
#
#           Artist_1         Artist_2 Artist_3 Artist_4 Artist_5
# 0    Elvis Presley             None      NaN      NaN      NaN
# 1    Frank Sinatra             None      NaN      NaN      NaN
# 2     The Platters             None      NaN      NaN      NaN
# 3      Ray Charles             None      NaN      NaN      NaN
# 4  Ella Fitzgerald  Louis Armstrong      NaN      NaN      NaN

# %% [markdown]
# ## Get Lyrics
#
# At this step, I am using the Spotify data to retrieve the lyrics from the Genius API. This is still an intermediate dataset for my analysis. I will get retrieve the top result from searching the Genius database using the Spotify track name.

# %%
def new_track_names(data):
    """
    Cleaning the song name from each instance in the data. This function uses regex to remove the "-" character from the song name from the Spotify data. 
    The cleaned name is what will be used to search the Genius API. 

    data: Pandas dataframe; ideally this is the dataset formed from the Spotify data.

    Example:
        Before: "I've Got You Under My Skin - Remastered 1998"
        After: "I've Got You Under My Skin"
    "
    """
    #clean song titles
    data["new_track_name"]=data["track_name"].str.replace("\s-.*","")
    data["new_track_name"] = data["new_track_name"].apply(lambda x: re.sub(r"\(.*\)","",x).strip())
    
    return data

# %%
genius_info = lambda df: [genius.search_song(title=df["new_track_name"][i], artist=df["Artist_1"][i]) for i in range(len(df))]
#lyrics_please = lambda List: ["None" if List[num] is None else List[num].lyrics.replace("\n"," ").replace("EmbedShare URLCopyEmbedCopy","") for num in range(len(List))]

def add_Genius_info(data):
    """
    This function adds the genius data to the data set. Here are the steps taken to engineer the data:
    1) Create an empty dataframe & create list of intervals by 25. I create this interval to track the progress of rows processed in the dataset. It also allows for some built in sleep
    time between each pull of data from the API.
    2) Retrieve lyrics, titles, and artists from the Genius API. The lyrics are pulled for text analysis but the Genius titles and artists are pulled for accuracy comparison. In a later step,
    the Genius vs Spotify comparison will be discussed.
    3) Set the columns from the Genius API for song lyrics, song titles, and artists & concat the data to the empty dataframe.

    The result will be a dataset with the Genius API data.
    """
    complete_data = pd.DataFrame()
    interval = list(range(0,len(data)+1,25))
    for i in range(len(interval)):
        try:
            print(interval[i], interval[i+1])
            part_data = data.iloc[interval[i]:interval[i+1],:].reset_index()
            lyrics, full_titles, artists = get_Genius_info(part_data)
            part_data["lyrics"] = lyrics
            part_data["g_full_titles"] = full_titles
            part_data["g_artists"] = artists
            complete_data = pd.concat([complete_data,part_data])
            time.sleep(10)
        except IndexError as e:
            if interval[i] == len(data):
                print("end")
    
    return complete_data
                
def get_Genius_info(data):
    """
    This function searches the Genius API to retrieve the song lyrics. This function is embedded in the add_Genius_info function.
    1) Retrieve Genius data using cleaned song title and artist from the data.
    2) Search the Genius data results for lyrics, song titles, and artists. Additionally, I clean the lyrics to remove unwanted jargon that exists in all entries.

    The result is several lists that will be used to create columns in the dataset for the add_Genius_info function.
    """
    retrieval = genius_info(data)
    lyrics = (list(map(lambda x: "None" if x is None else itemgetter("lyrics")(x.to_dict()).replace("\n"," ").replace("EmbedShare URLCopyEmbedCopy",""),retrieval)))
    full_titles = (list(map(lambda x: "None" if x is None else itemgetter("full_title")(x.to_dict()), retrieval)))
    artists = (list(map(lambda x: "None" if x is None else itemgetter("artist")(x.to_dict()),retrieval)))
    
    return lyrics, full_titles, artists

# %% [markdown]
# #### Run the functions!

# %%
full_data = new_track_names(full_data)
# complete_data = add_Genius_info(full_data)
# Out:
# 0 25
# Searching for "Don't Be Cruel" by Elvis Presley...
# Done.
# Searching for "I've Got You Under My Skin" by Frank Sinatra...
# Done.
# Searching for "Smoke Gets In Your Eyes" by The Platters...
# Done.
# Searching for "What'd I Say, Pt. 1 & 2" by Ray Charles...
# Done.
# Searching for "Dream A Little Dream Of Me" by Ella Fitzgerald...
# Done.
# Searching for "That'll Be The Day" by Buddy Holly...
# Done.
# Searching for "Blueberry Hill" by Fats Domino...
# Done.
# Searching for "I Kissed You" by The Everly Brothers...
# Done.
# Searching for "That's Amore" by Dean Martin...
# Done.
# Searching for "Baby" by Dinah Washington...
# Done.
# Searching for "Hound Dog" by Elvis Presley...
# Done.
# Searching for "Twilight Time" by The Platters...
# Done.
# Searching for "Pennies From Heaven" by Louis Prima...
# Done.
# Searching for "It's Only Make Believe" by Conway Twitty...
# Done.
# Searching for "Rags To Riches" by Tony Bennett...
# Done.
# Searching for "Everyday" by Buddy Holly...
# Done.
# Searching for "The Great Pretender" by The Platters...
# Done.
# Searching for "Bye Bye Love" by The Everly Brothers...
# Done.
# Searching for "Love Me Tender" by Elvis Presley...
# Done.
# Searching for "Somethin' Else" by Eddie Cochran...
# Done.
# Searching for "Beyond the Sea" by Bobby Darin...
# Done.
# Searching for "Alone" by Alan Walker...
# Done.
# 1025 1050
# Searching for "I Took A Pill In Ibiza" by Mike Posner...
# Done.
# Searching for "FRIENDS" by Marshmello...
# Done.
# Searching for "Titanium" by David Guetta...
# Done.
# Searching for "All I Ask" by Adele...
# Done.
# Searching for "Friends" by Justin Bieber...
# Done.
# Searching for "Dancing With A Stranger" by Sam Smith...
# Done.
# Searching for "Sunflower" by Post Malone...
# Done.
# Searching for "Domino" by Jessie J...
# Done.
# Searching for "She Looks So Perfect" by 5 Seconds of Summer...
# Done.
# Searching for "Attention" by Charlie Puth...
# Done.
# Searching for "2U" by David Guetta...
# Done.
# Searching for "Remind Me to Forget" by Kygo...
# Done.
# Searching for "Cake By The Ocean" by DNCE...
# Done.
# Searching for "Moves Like Jagger" by Maroon 5...
# Done.
# Searching for "Dance Monkey" by Tones And I...
# Done.
# Searching for "Firework" by Katy Perry...
# Done.
# Searching for "The Edge Of Glory" by Lady Gaga...
# Done.
# Searching for "Cool Kids" by Echosmith...
# Done.
# Searching for "Flashlight" by Jessie J...
# Done.
# Searching for "It's Not Living" by The 1975...
# Done.
# Searching for "Dancing On My Own" by Calum Scott...
# Done.
# Searching for "1950" by King Princess...
# Done.
# Searching for "In My Blood" by Shawn Mendes...
# Done.
# Searching for "It's a Beautiful Day" by Michael Bublé...
# Done.
# Searching for "These Days" by Rudimental...
# Done.
# ---------------------------------------------------------------------------
#
# IndexError                                Traceback (most recent call last)
#
# <ipython-input-21-6aa5d6a64a43> in add_Genius_info(data)
#
#       8         try:
#
# ----> 9             print(interval[i], interval[i+1])
#
#      10             part_data = data.iloc[interval[i]:interval[i+1],:].reset_index()
#
#
#
# IndexError: list index out of range
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# NameError                                 Traceback (most recent call last)
#
# <ipython-input-29-9f13b2594e29> in <module>
#
#       1 full_data = new_track_names(full_data)
#
# ----> 2 complete_data = add_Genius_info(full_data)
#
#
#
# <ipython-input-21-6aa5d6a64a43> in add_Genius_info(data)
#
#      16             time.sleep(10)
#
#      17         except IndexError as e:
#
# ---> 18             if by25[i] == len(data):
#
#      19                 print("end")
#
#      20
#
#
#
# NameError: name 'by25' is not defined

# %%
#Adding the decades to the database. This will allow for easier filtering when I want to poke around in the data.
decades = dict(zip(list(data.playlist_id.unique()),["1950s","1960s","1970s","1980s","1990s","2000s","2010s"]))
def map_values(row, values_dict):
    return values_dict[row]

complete_data['playlist_name'] = complete_data['playlist_id'].apply(map_values, args = (decades,))

# %%
complete_data.head()
# Out:
#    index album_release_date album_type  \
# 0      0         1958-03-21      album
# 1      1            1956-03      album
# 2      2         1995-01-01      album
# 3      3               1959      album
# 4      4         1996-06-04      album
#
#                                 album_name  track_explicit  track_track  \
# 0                    Elvis' Golden Records           False         True
# 1  Songs For Swingin' Lovers! (Remastered)           False         True
# 2                 The Best Of The Platters           False         True
# 3                             What'd I Say           False         True
# 4                           Ella & Friends           False         True
#
#                                      track_name                track_id  \
# 0                                Don't Be Cruel  01u6AEzGbGbQyYVdxajxqk
# 1  I've Got You Under My Skin - Remastered 1998  3aEJMh1cXKEjgh52claxQp
# 2                       Smoke Gets In Your Eyes  307XEC1IUwUs9ojlEFwH7f
# 3                       What'd I Say, Pt. 1 & 2  5yQ9iMZXGcr5rlO4hoLsP4
# 4                    Dream A Little Dream Of Me  3vFVS2WYHDG4KkWCNecvpn
#
#               playlist_id  multiple_artists         Artist_1         Artist_2  \
# 0  37i9dQZF1DWSV3Tk4GO2fq             False    Elvis Presley              NaN
# 1  37i9dQZF1DWSV3Tk4GO2fq             False    Frank Sinatra              NaN
# 2  37i9dQZF1DWSV3Tk4GO2fq             False     The Platters              NaN
# 3  37i9dQZF1DWSV3Tk4GO2fq             False      Ray Charles              NaN
# 4  37i9dQZF1DWSV3Tk4GO2fq              True  Ella Fitzgerald  Louis Armstrong
#
#   Artist_3 Artist_4 Artist_5              new_track_name  \
# 0      NaN      NaN      NaN              Don't Be Cruel
# 1      NaN      NaN      NaN  I've Got You Under My Skin
# 2      NaN      NaN      NaN     Smoke Gets In Your Eyes
# 3      NaN      NaN      NaN     What'd I Say, Pt. 1 & 2
# 4      NaN      NaN      NaN  Dream A Little Dream Of Me
#
#                                               lyrics  \
# 0  You know I can be found Sitting home all alone...
# 1  I've got you under my skin I've got you deep i...
# 2  They asked me how I knew My true love was true...
# 3  Hey mama, don't you treat me wrong Come and lo...
# 4  Stars shining bright above you Night breezes s...
#
#                                        g_full_titles  \
# 0                    Don't Be Cruel by Elvis Presley
# 1        I've Got You Under My Skin by Frank Sinatra
# 2            Smoke Gets in Your Eyes by The Platters
# 3          What'd I Say (Parts 1 & 2) by Ray Charles
# 4  Dream a Little Dream of Me by Ella Fitzgerald ...
#
#                            g_artists playlist_name
# 0                      Elvis Presley         1950s
# 1                      Frank Sinatra         1950s
# 2                       The Platters         1950s
# 3                        Ray Charles         1950s
# 4  Ella Fitzgerald & Louis Armstrong         1950s

# %% [markdown]
# ## Get Lyrics, Part 2
#
# In my exploration of the API functions and data, I found that Genius did not always match the exact song that was in the data. I decided to assign a fuzzy matching score to the Genius song title pulled from the API. This score will compare the Genius song title to the Spotify song title. If the Genius song title received a score of 80 or higher, the lyrics will be used in the explicit word analysis. Otherwise, that song will be dropped.

# %%
#resetting the index - I assume it is due to dropping and adding rows and columns
complete_data = complete_data.reset_index().drop(columns=["level_0","index"])

#obtaining the song title from the genius results - Before: "Jenny From The Block by Jennifer Lopez", After: "Jenny From The Block"
complete_data["g_title"] = complete_data["g_full_titles"].apply(lambda x: re.sub(r"\sby.*","",x).strip())

#creating a lambda function to calculate fuzzy matching ratio between Genius and Spotify song titles
score = lambda df,x,y: [fuzz.ratio(df[x][i].lower(), df[y][i].lower()) for i in range(len(df))]

# creating a column with the fuzzy matching score
complete_data["title_match_score"] = score(complete_data,"new_track_name","g_title")

#creating a pass/fail column based on the fuzzy matching score
complete_data["title_pass_fail"] = complete_data["title_match_score"].apply(lambda x: "fail" if x < 80 else "pass")

# %% [markdown]
# ## Clean Up Lyrics
# I have retrieved all of the lyrics!!! Now I need to clean the lyrics before analysis. Below I outlined my order of operations to clean the lyrics. The result of each row will be a set of words used in the lyrics. By default, a set will include the unique words used not all of the iterations of the word.
#
# #### Order of Operations
# * Break apart contractions - Since I use the stop words set from nltk, it doesn't typically include contractions (didn't to did not). Before I removed punctuation, I broke apart the contractions to prepare for stopword removal.
# * Remove Punctuation - Since I'm reviewing the text on a word level, I didn't care for the syntax of the lyrics.
# * Remove Stopwords - Removing words such as "she", "the", "as" to review important words
# * Remove Duplicates - I wanted to focus on if an explicit word appeared and not the multiple times the word occurred.

# %%
def prep_lyric_cleanup():
    """
    This function was created to prep the contractions dictionary and punctuation list to clean up the lyrics.
    1) Load contractions dictionary
    2) Split the dictionary and apply lowercase function to keys and values
    3) Zip the contractions dictionary back
    4) Drop months of the year keys from the contractions dictionary - Frankly, I felt it didn't matter so I dropped them.
    5) Create a punctuation translation list

    Output: lowercase contractions dictionary, translation list

    These outputs will be used to break apart contractions and remove punctuation.
    """
    cont_dict = contractions.contractions_dict
    lower_keys = [x.lower() for x in list(cont_dict.keys())]
    lower_values = [x.lower() for x in list(cont_dict.values())]
    lower_dict = dict(zip(lower_keys,lower_values))
    
    drop_keys = ['jan.','feb.','mar.','apr.','jun.','jul.','aug.','sep.','oct.','nov.','dec.']
    for key in drop_keys:
        lower_dict.pop(key)
   
    translation= str.maketrans("","",string.punctuation)
    
    return lower_dict, translation
    
def clean_it_up(lyrics):
    """
    This function cleans the lyrics for analysis.
    1) Apply lowercase function to lyrics
    2) Create a list of words by splitting the lyrics
    3) Break apart contractions using the contraction dictionary
    4) Remove punctuation using translation function
    5) Remove stop words using nltk's stop words set
    6) Remove duplicate words - The analysis is focused on word choice and not the number of times a word is used.
    """
    lower_lyrics = lyrics.lower()
    list_lyrics = lower_lyrics.split(" ")
    #break apart contractions
    processing1 = [lower_dict[word] if word in list(lower_dict.keys()) else word for word in list_lyrics]
    #remove punctuation
    processing2 = " ".join(processing1).translate(translation).split(" ")
    #remove stop words
    processing3 = [word for word in processing2 if word not in en_stop]
    #remove duplicates
    final_lyrics = set(processing3)#list(set(processing3))
    
    return final_lyrics

# %%
#Load the contractions dictionary (lowercase) & punctuation translation list
lower_dict, translation = prep_lyric_cleanup()
# Create a cleaned lyrics columns using the cleaning lyrics functionv
data["cleaned_lyrics"] = data["lyrics"].apply(clean_it_up)

# %% [markdown]
# ## Explicit Word Count Analysis
#
# I am finally at the point where the data is ready to be analyzed. I created a few functions here that will analyze the explicit word count in the lyrics and add the additional columns to the data.
#
# Explicit Word Lists Used:
# * Carnegie Mellon Explicit Word List - This list was obtained from a research group at Carnegie Mellon.
#     * Thoughts After Analysis: I felt that this list was too rigid for my analysis. There were words included that aren't typically considered explicit like fire.
# * YouTube Explicit List - A list obtained from a random site claimed to be updated to January 2021.
#     * Thoughts After Analysis: This list was exactly what I was looking for. I based my analysis more strongly on this list but I did still calculate the word count using the CMU list.

# %%
def create_explicit_word_dictionary():
    """
    This function cleans up the explicit word lists to prepare for analysis usage. In my EDA of the list,
    there were some repeats in words and excessive amounts of blanks. 

    1) Create a lambda: This function will create a list that will strip empty spaces on either side of a word.
    2) Read in the explicit word lists from CMU and YouTube.
    3) Apply the lambda function to the explicit word lists to clean up the documents.
    4) Clean up CMU list - I found some repeats and pecularities in this list so I added a few additional actions.
    5) Create Dictionary - A dictionary is created with two key/value pairs.
        * YT : List of YT Explicit Words
        * CMU: List of CMU Explicit Words
    """
    clean_it_up_lines = lambda List: [List[num].strip() for num in range(len(List))]
    
    with open('cmu_offensive_word_list.txt') as f:
        lines_cmu = f.readlines()
    with open('youtube-blacklist-words-list_comma-separated-text-file_2021-01-19.txt') as h:
        lines_yt = h.readlines()
        
    yt_explicit = set(clean_it_up_lines(lines_yt[13].split(",")))
    cmu_explicit = clean_it_up_lines(lines_cmu)
    
    #additional cleanup for cmu
    cmu_explicit.pop(0)
    cmu_explicit = set(cmu_explicit)
    
    explicit_dict = dict(zip(["yt","cmu"],[yt_explicit,cmu_explicit]))
    
    return explicit_dict

# %%
def get_explicit_columns(data, explicit_dict):
    """
    This function executes the explicit word count analysis and creates 2 new columns to append to the data set:
        * Explicit Words - The explicit words found in the lyrics when compared to explicit word list
        * Explicit Word Count - The number of explicit words found in the lyrics
    """
    new_data = data.copy()
    #for each explicit list in the explicit word dictionary
    for List in explicit_dict.keys():
        #find the words that intersect between the song lyrics and explicit word list (CMU or YT)
        explicit_set = new_data["cleaned_lyrics"].apply(lambda x: explicit_dict[List].intersection(set(x)))
        #count the explicit words found
        explicit_count = explicit_set.apply(lambda x: len(x))
        #create column with the explicit words found
        new_data[List+"_explicit_words_2"] = explicit_set
        #create column with the explicit word count
        new_data[List+"_explicit_count_2"] = explicit_count
    
    return new_data

# %%
#create an explicit word dictionary using CMU and YT explicit word lists
explicit_dict = create_explicit_word_dictionary()
#create the final dataset for analysis
final_data = get_explicit_columns(data, explicit_dict)

# %%
# drop rows where lyrics were not found
complete = final_data.drop(final_data[final_data.lyrics=="None"].index)
# drop rows where the matching title score was less than 80
complete = complete.drop(complete[complete.title_match_score < 80].index)

# %% [markdown]
# ## Results
#
# Below are the results of my lyric analysis. For each decade, I've calculated summary statistics. I also completed a t-test to compare the explicit word count of the decades.
#
# There is also a Tableau dashboard that shows the data in a more interactive way. The results below are more for the nerds like me :)

# %% [markdown]
# ### Summary Statistics

# %%
def get_stats(df, explicit_word_count_column):
    """
    The calculation of summary statistics for each decade.

    df: data, pandas DataFrame
    explicit_word_count_column: the name of the column; yt_explicit_count or cmu_explicit_count
    """
    for keys in list(decades.keys()):
        print("*"*50)
        decade_df = df[df.playlist_id == keys][explicit_word_count_column].describe()
        print("total: ", decade_df["count"])
        print("decade: ", decades[keys])
        print("average: ", round(decade_df["mean"],2))
        print("median: ", round(decade_df["50%"],2))
        print("max: ", decade_df["max"])
        print("song w/ most explicit words: ", list(df[(df[explicit_word_count_column] == decade_df["max"])&(df["playlist_name"]==decades[keys])]["track_name"].values))

# %%
#summary statistics of each decade using the Carnegie Mellon explicit word list
get_stats(data,"cmu_explicit_count")
# Out:
# **************************************************
# total:  139.0
# decade:  1950s
# average:  0.58
# median:  0.0
# max:  5.0
# song w/ most explicit words:  ['Manhattan']
# **************************************************
# total:  133.0
# decade:  1960s
# average:  0.76
# median:  0.0
# max:  8.0
# song w/ most explicit words:  ['Sympathy For The Devil']
# **************************************************
# total:  141.0
# decade:  1970s
# average:  1.22
# median:  1.0
# max:  12.0
# song w/ most explicit words:  ['American Pie']
# **************************************************
# total:  142.0
# decade:  1980s
# average:  0.84
# median:  1.0
# max:  11.0
# song w/ most explicit words:  ["We Didn't Start the Fire"]
# **************************************************
# total:  135.0
# decade:  1990s
# average:  1.3
# median:  1.0
# max:  6.0
# song w/ most explicit words:  ["Freedom! '90 - Remastered", 'Ironic - 2015 Remaster', "Let's Talk About Sex"]
# **************************************************
# total:  141.0
# decade:  2000s
# average:  2.82
# median:  2.0
# max:  16.0
# song w/ most explicit words:  ['Run This Town']
# **************************************************
# total:  144.0
# decade:  2010s
# average:  1.71
# median:  1.0
# max:  7.0
# song w/ most explicit words:  ['Super Bass', '7 rings', 'Taki Taki (with Selena Gomez, Ozuna & Cardi B)']

# %%
#summary statistics of each decade using the YouTube explicit word list
get_stats(data,"yt_explicit_count")
# Out:
# **************************************************
# total:  139.0
# decade:  1950s
# average:  0.22
# median:  0.0
# max:  3.0
# song w/ most explicit words:  ['Bo Diddley']
# **************************************************
# total:  133.0
# decade:  1960s
# average:  0.23
# median:  0.0
# max:  3.0
# song w/ most explicit words:  ['Like a Rolling Stone']
# **************************************************
# total:  141.0
# decade:  1970s
# average:  0.35
# median:  0.0
# max:  3.0
# song w/ most explicit words:  ['Sultans Of Swing', 'The Ballroom Blitz']
# **************************************************
# total:  142.0
# decade:  1980s
# average:  0.2
# median:  0.0
# max:  4.0
# song w/ most explicit words:  ["We Didn't Start the Fire"]
# **************************************************
# total:  135.0
# decade:  1990s
# average:  0.34
# median:  0.0
# max:  4.0
# song w/ most explicit words:  ["Let's Talk About Sex"]
# **************************************************
# total:  141.0
# decade:  2000s
# average:  1.73
# median:  1.0
# max:  15.0
# song w/ most explicit words:  ['Without Me']
# **************************************************
# total:  144.0
# decade:  2010s
# average:  0.75
# median:  0.0
# max:  7.0
# song w/ most explicit words:  ['Taki Taki (with Selena Gomez, Ozuna & Cardi B)']

# %%
data = pd.read_csv("Final_data_w_explicit.csv")

# %% [markdown]
# ### Comparing Decades' Explicit Word Count
#
# By performing t-tests, I compared all of the decades to each other. In the summary statistics, I did find that the later decades had a higher average explicit word count. Now I want to see if any of my results were significant.
#
# Results - I did find that the later decades (2000s and 2010s) typically had significant results having more words than previous decades.

# %%
#create all possible pairs for the decades
decade_pairs = [(a, b) for idx, a in enumerate(list(data["playlist_name"].unique())) for b in list(data["playlist_name"].unique())[idx + 1:]]

# %%
for pair in decade_pairs:
    #filter data by decade 1
    decade1 = data[data["playlist_name"]==pair[0]]
    #filter data by decade 2
    decade2 = data[data["playlist_name"]==pair[1]]
    #t-test comparing the decade 2 to the mean of decade 1
    test_results = ss.ttest_1samp(decade2["yt_explicit_count"],decade1["yt_explicit_count"].mean())
    #print results
    print(pair[0], "vs.", pair[1])
    print(f'The {pair[1]} has {"significantly" if test_results[1] < 0.05 else ""} {"more" if test_results[0] > 0 else "less"} explicit words than the {pair[0]}.')
    print("t-statistic:", round(test_results[0],2), "p-value:", round(test_results[1],3))
    print("*"*50)
# Out:
# 1950s vs. 1960s
# The 1960s has  more explicit words than the 1950s.
# t-statistic: 0.05 p-value: 0.957
# **************************************************
# 1950s vs. 1970s
# The 1970s has significantly more explicit words than the 1950s.
# t-statistic: 2.34 p-value: 0.021
# **************************************************
# 1950s vs. 1980s
# The 1980s has  less explicit words than the 1950s.
# t-statistic: -0.43 p-value: 0.671
# **************************************************
# 1950s vs. 1990s
# The 1990s has  more explicit words than the 1950s.
# t-statistic: 1.94 p-value: 0.054
# **************************************************
# 1950s vs. 2000s
# The 2000s has significantly more explicit words than the 1950s.
# t-statistic: 6.84 p-value: 0.0
# **************************************************
# 1950s vs. 2010s
# The 2010s has significantly more explicit words than the 1950s.
# t-statistic: 5.44 p-value: 0.0
# **************************************************
# 1960s vs. 1970s
# The 1970s has significantly more explicit words than the 1960s.
# t-statistic: 2.29 p-value: 0.024
# **************************************************
# 1960s vs. 1980s
# The 1980s has  less explicit words than the 1960s.
# t-statistic: -0.48 p-value: 0.63
# **************************************************
# 1960s vs. 1990s
# The 1990s has  more explicit words than the 1960s.
# t-statistic: 1.9 p-value: 0.059
# **************************************************
# 1960s vs. 2000s
# The 2000s has significantly more explicit words than the 1960s.
# t-statistic: 6.83 p-value: 0.0
# **************************************************
# 1960s vs. 2010s
# The 2010s has significantly more explicit words than the 1960s.
# t-statistic: 5.42 p-value: 0.0
# **************************************************
# 1970s vs. 1980s
# The 1980s has significantly less explicit words than the 1970s.
# t-statistic: -3.24 p-value: 0.001
# **************************************************
# 1970s vs. 1990s
# The 1990s has  less explicit words than the 1970s.
# t-statistic: -0.11 p-value: 0.911
# **************************************************
# 1970s vs. 2000s
# The 2000s has significantly more explicit words than the 1970s.
# t-statistic: 6.27 p-value: 0.0
# **************************************************
# 1970s vs. 2010s
# The 2010s has significantly more explicit words than the 1970s.
# t-statistic: 4.16 p-value: 0.0
# **************************************************
# 1980s vs. 1990s
# The 1990s has significantly more explicit words than the 1980s.
# t-statistic: 2.25 p-value: 0.026
# **************************************************
# 1980s vs. 2000s
# The 2000s has significantly more explicit words than the 1980s.
# t-statistic: 6.92 p-value: 0.0
# **************************************************
# 1980s vs. 2010s
# The 2010s has significantly more explicit words than the 1980s.
# t-statistic: 5.64 p-value: 0.0
# **************************************************
# 1990s vs. 2000s
# The 2000s has significantly more explicit words than the 1990s.
# t-statistic: 6.3 p-value: 0.0
# **************************************************
# 1990s vs. 2010s
# The 2010s has significantly more explicit words than the 1990s.
# t-statistic: 4.23 p-value: 0.0
# **************************************************
# 2000s vs. 2010s
# The 2010s has significantly less explicit words than the 2000s.
# t-statistic: -10.13 p-value: 0.0
# **************************************************

# %%
for pair in decade_pairs:
    #filter data by decade 1
    decade1 = data[data["playlist_name"]==pair[0]]
    #filter data by decade 2
    decade2 = data[data["playlist_name"]==pair[1]]
    #t-test comparing the decade 2 to the mean of decade 1
    test_results = ss.ttest_1samp(decade2["cmu_explicit_count"],decade1["cmu_explicit_count"].mean())
    #print results
    print(pair[0], "vs.", pair[1])
    print(f'The {pair[1]} has {"significantly" if test_results[1] < 0.05 else ""} {"more" if test_results[0] > 0 else "less"} explicit words than the {pair[0]}.')
    print("t-statistic:", round(test_results[0],2), "p-value:", round(test_results[1],3))
    print("*"*50)
# Out:
# 1950s vs. 1960s
# The 1960s has  more explicit words than the 1950s.
# t-statistic: 1.89 p-value: 0.061
# **************************************************
# 1950s vs. 1970s
# The 1970s has significantly more explicit words than the 1950s.
# t-statistic: 4.74 p-value: 0.0
# **************************************************
# 1950s vs. 1980s
# The 1980s has significantly more explicit words than the 1950s.
# t-statistic: 2.53 p-value: 0.012
# **************************************************
# 1950s vs. 1990s
# The 1990s has significantly more explicit words than the 1950s.
# t-statistic: 5.94 p-value: 0.0
# **************************************************
# 1950s vs. 2000s
# The 2000s has significantly more explicit words than the 1950s.
# t-statistic: 8.02 p-value: 0.0
# **************************************************
# 1950s vs. 2010s
# The 2010s has significantly more explicit words than the 1950s.
# t-statistic: 8.21 p-value: 0.0
# **************************************************
# 1960s vs. 1970s
# The 1970s has significantly more explicit words than the 1960s.
# t-statistic: 3.39 p-value: 0.001
# **************************************************
# 1960s vs. 1980s
# The 1980s has  more explicit words than the 1960s.
# t-statistic: 0.76 p-value: 0.45
# **************************************************
# 1960s vs. 1990s
# The 1990s has significantly more explicit words than the 1960s.
# t-statistic: 4.43 p-value: 0.0
# **************************************************
# 1960s vs. 2000s
# The 2000s has significantly more explicit words than the 1960s.
# t-statistic: 7.36 p-value: 0.0
# **************************************************
# 1960s vs. 2010s
# The 2010s has significantly more explicit words than the 1960s.
# t-statistic: 6.88 p-value: 0.0
# **************************************************
# 1970s vs. 1980s
# The 1980s has significantly less explicit words than the 1970s.
# t-statistic: -3.68 p-value: 0.0
# **************************************************
# 1970s vs. 1990s
# The 1990s has  more explicit words than the 1970s.
# t-statistic: 0.63 p-value: 0.53
# **************************************************
# 1970s vs. 2000s
# The 2000s has significantly more explicit words than the 1970s.
# t-statistic: 5.71 p-value: 0.0
# **************************************************
# 1970s vs. 2010s
# The 2010s has significantly more explicit words than the 1970s.
# t-statistic: 3.54 p-value: 0.001
# **************************************************
# 1980s vs. 1990s
# The 1990s has significantly more explicit words than the 1980s.
# t-statistic: 3.78 p-value: 0.0
# **************************************************
# 1980s vs. 2000s
# The 2000s has significantly more explicit words than the 1980s.
# t-statistic: 7.08 p-value: 0.0
# **************************************************
# 1980s vs. 2010s
# The 2010s has significantly more explicit words than the 1980s.
# t-statistic: 6.31 p-value: 0.0
# **************************************************
# 1990s vs. 2000s
# The 2000s has significantly more explicit words than the 1990s.
# t-statistic: 5.44 p-value: 0.0
# **************************************************
# 1990s vs. 2010s
# The 2010s has significantly more explicit words than the 1990s.
# t-statistic: 2.99 p-value: 0.003
# **************************************************
# 2000s vs. 2010s
# The 2010s has significantly less explicit words than the 2000s.
# t-statistic: -8.03 p-value: 0.0
# **************************************************
